# %%
import sys 
sys.path.append('./../../src')

# python shit
from datetime import datetime

# my shit
from lib.finnhub.data import FinnhubData as finnhub
from lib.oscillators import macd_over_period, stochastic_over_period
from lib.charts import chart

# %%
ticker = 'dkng'

fh = finnhub()
data = fh.get_historical_data(ticker, fh.get_daily_closings, days = 180, include_ah = False)

data.index = data['t']
data.sort_index()
data.drop_duplicates()
# Out:
#                                       t        o        l        h        c  \
# t
# 2021-01-19 20:00:00 2021-01-19 20:00:00  51.1600  51.7900  51.2800  51.8895
# 2021-01-20 20:00:00 2021-01-20 20:00:00  52.8901  53.0459  53.1550  53.2800
# 2021-01-21 20:00:00 2021-01-21 20:00:00  53.3600  53.8200  53.5600  53.9000
# 2021-01-22 20:00:00 2021-01-22 20:00:00  52.4700  53.0500  52.5000  53.0900
# 2021-01-25 20:00:00 2021-01-25 20:00:00  51.1600  51.6400  51.3300  51.7400
# 2021-01-26 20:00:00 2021-01-26 20:00:00  53.8000  55.0300  54.0600  55.0300
# 2021-01-27 20:00:00 2021-01-27 20:00:00  53.4400  54.1189  54.3200  54.4700
# 2021-01-28 20:00:00 2021-01-28 20:00:00  55.8300  57.5450  56.1700  57.6700
# 2021-01-29 20:00:00 2021-01-29 20:00:00  53.9300  54.1999  54.1400  54.6000
# 2021-02-01 20:00:00 2021-02-01 20:00:00  54.4000  55.0599  54.6400  55.1600
# 2021-02-02 20:00:00 2021-02-02 20:00:00  58.5000  59.5999  59.3000  60.3000
# 2021-02-03 20:00:00 2021-02-03 20:00:00  59.6551  60.2000  60.1200  60.3700
# 2021-02-04 20:00:00 2021-02-04 20:00:00  62.8800  62.8800  63.0100  63.0100
# 2021-02-05 18:00:00 2021-02-05 18:00:00  64.0500  64.0500  64.0500  64.0500
# 2021-02-08 20:00:00 2021-02-08 20:00:00  60.9300  61.5001  61.9600  62.1500
# 2021-02-09 20:00:00 2021-02-09 20:00:00  61.8450  62.3300  62.1400  62.4100
# 2021-02-10 20:00:00 2021-02-10 20:00:00  62.3400  63.2100  62.7100  63.2800
# 2021-02-11 20:00:00 2021-02-11 20:00:00  59.1400  59.4395  59.1900  59.7700
# 2021-02-12 20:00:00 2021-02-12 20:00:00  60.7500  60.9300  61.0600  61.1100
# 2021-02-16 20:00:00 2021-02-16 20:00:00  60.3900  60.7500  60.5292  60.8900
# 2021-02-17 20:00:00 2021-02-17 20:00:00  58.8200  59.0830  58.9100  59.3400
# 2021-02-18 20:00:00 2021-02-18 20:00:00  58.1500  58.3600  58.3200  58.6600
# 2021-02-19 20:00:00 2021-02-19 20:00:00  60.4500  60.9899  60.9100  61.0100
# 2021-02-22 20:00:00 2021-02-22 20:00:00  60.1740  61.8800  60.3600  61.8900
# 2021-02-23 20:00:00 2021-02-23 20:00:00  59.5606  59.6400  60.2700  60.4400
# 2021-02-24 20:00:00 2021-02-24 20:00:00  59.5700  59.5850  60.2800  60.4800
# 2021-02-25 20:00:00 2021-02-25 20:00:00  57.2100  58.6700  57.8200  58.6800
# 2021-02-26 20:00:00 2021-02-26 20:00:00  60.7500  61.3600  61.5300  61.8500
# 2021-03-01 20:00:00 2021-03-01 20:00:00  67.5700  68.3700  68.7300  68.9000
# 2021-03-02 20:00:00 2021-03-02 20:00:00  68.4000  70.1300  68.5800  70.3399
# 2021-03-03 20:00:00 2021-03-03 20:00:00  65.4600  66.7950  65.7300  67.1000
# 2021-03-04 20:00:00 2021-03-04 20:00:00  61.1000  61.9900  61.9100  62.1600
# 2021-03-05 20:00:00 2021-03-05 20:00:00  59.3822  59.8599  59.5550  60.0000
# 2021-03-08 20:00:00 2021-03-08 20:00:00  60.2600  61.1700  60.5400  61.2200
# 2021-03-09 20:00:00 2021-03-09 20:00:00  62.0700  63.0000  62.1600  63.3578
# 2021-03-10 20:00:00 2021-03-10 20:00:00  68.9200  69.9400  69.2900  70.2900
# 2021-03-11 20:00:00 2021-03-11 20:00:00  70.8100  70.9000  71.6200  71.6300
# 2021-03-12 20:00:00 2021-03-12 20:00:00  70.5600  70.6900  71.7462  71.9500
# 2021-03-15 20:00:00 2021-03-15 20:00:00  67.7500  67.7500  67.7500  67.7500
# 2021-03-16 20:00:00 2021-03-16 20:00:00  67.1400  67.1400  67.1400  67.1400
# 2021-03-17 13:00:00 2021-03-17 13:00:00  65.1900  65.8333  68.0600  68.2098
#
#                            v
# t
# 2021-01-19 20:00:00  2271451
# 2021-01-20 20:00:00  1420270
# 2021-01-21 20:00:00  1332427
# 2021-01-22 20:00:00  1546287
# 2021-01-25 20:00:00  1516603
# 2021-01-26 20:00:00  2214945
# 2021-01-27 20:00:00  2824486
# 2021-01-28 20:00:00  3327494
# 2021-01-29 20:00:00  2590310
# 2021-02-01 20:00:00  1464883
# 2021-02-02 20:00:00  3608586
# 2021-02-03 20:00:00  1640813
# 2021-02-04 20:00:00  3598477
# 2021-02-05 18:00:00        0
# 2021-02-08 20:00:00  2475337
# 2021-02-09 20:00:00  2010531
# 2021-02-10 20:00:00  1067632
# 2021-02-11 20:00:00  1870685
# 2021-02-12 20:00:00   991303
# 2021-02-16 20:00:00   941867
# 2021-02-17 20:00:00   891831
# 2021-02-18 20:00:00  1156800
# 2021-02-19 20:00:00  1423123
# 2021-02-22 20:00:00  1733905
# 2021-02-23 20:00:00  2052196
# 2021-02-24 20:00:00  1162045
# 2021-02-25 20:00:00  2347634
# 2021-02-26 20:00:00  2766325
# 2021-03-01 20:00:00  3514157
# 2021-03-02 20:00:00  2676078
# 2021-03-03 20:00:00  3242729
# 2021-03-04 20:00:00  2925140
# 2021-03-05 20:00:00  2310808
# 2021-03-08 20:00:00  3229489
# 2021-03-09 20:00:00  2295842
# 2021-03-10 20:00:00  4255611
# 2021-03-11 20:00:00  2427653
# 2021-03-12 20:00:00  2073413
# 2021-03-15 20:00:00        0
# 2021-03-16 20:00:00        0
# 2021-03-17 13:00:00  1708227

# %%
days = 60

chart_data = list(data['c'].tail(days))

macd_vals = macd_over_period(list(data['c']), days)

macd_line = list([i[0] for i in macd_vals])[-1-days:-1]
sig_line = list([i[1] for i in macd_vals])[-1-days:-1]
histo = list([i[2] for i in macd_vals])[-1-days:-1]

oscillator_dicts = [
    { 'chart': 'line', 'data': macd_line, 'label': 'macd' },
    { 'chart': 'line', 'data': sig_line, 'label': 'signal' },
    { 'chart': 'bar', 'data': histo, 'label': ''}
]

data_dicts = [
    { 'label': 'close', 'data': chart_data }
]

chart(ticker, data_dicts, oscillator_dicts)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-ff97dca3da7f> in <module>
#       3 chart_data = list(data['c'].tail(days))
#       4
# ----> 5 macd_vals = macd_over_period(list(data['c']), days)
#       6
#       7 macd_line = list([i[0] for i in macd_vals])[-1-days:-1]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in macd_over_period(vals, period)
#      47 def macd_over_period(vals, period):
#      48     m_vals = list([macd(vals[:-i]) for i in range(len(vals)-26, 0, -1)])
# ---> 49     ms_vals = list([ema(m_vals[:-i], 9, 2) for i in range(period, 0, -1)])
#      50     real_m_vals = m_vals[-period-1:-1]
#      51     histos = [t[0] - t[1] for t in list(zip(real_m_vals, ms_vals))]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in <listcomp>(.0)
#      47 def macd_over_period(vals, period):
#      48     m_vals = list([macd(vals[:-i]) for i in range(len(vals)-26, 0, -1)])
# ---> 49     ms_vals = list([ema(m_vals[:-i], 9, 2) for i in range(period, 0, -1)])
#      50     real_m_vals = m_vals[-period-1:-1]
#      51     histos = [t[0] - t[1] for t in list(zip(real_m_vals, ms_vals))]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in ema(d, period, smoothing)
#      38     for i in range(0, period):
#      39         if i == 0:
# ---> 40             sma_val = sma(d)
#      41             vals = vals + [int(d[-period]) * k + sma_val]
#      42         else:
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in sma(vals)
#      19
#      20 def sma(vals):
# ---> 21     return sum(vals) / len(vals)
#      22
#      23 def fastk(vals):
#
# ZeroDivisionError: division by zero

# %%
stochastic_vals = stochastic_over_period(list(data['c']), days)

fastk_data = list([i[0] for i in stochastic_vals])
slowd_data = list([i[2] for i in stochastic_vals])

oscillator_dicts = [
    { 'chart': 'line', 'data': fastk_data, 'label': 'fastk'},
    { 'chart': 'line', 'data': slowd_data, 'label': 'slowd'}
]

data_dicts = [
    { 'label': 'close', 'data': chart_data }
]

chart(ticker, data_dicts, oscillator_dicts)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-5c3eda815a4e> in <module>
# ----> 1 stochastic_vals = stochastic_over_period(list(data['c']), days)
#       2
#       3 fastk_data = list([i[0] for i in stochastic_vals])
#       4 slowd_data = list([i[2] for i in stochastic_vals])
#       5
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in stochastic_over_period(vals, period, fastk_days, slowk_days, slowd_days)
#      12     ret_vals = [[0, 0, 0]] * period
#      13     for i in range(0, period):
# ---> 14         fastk, slowk, slowd = stochastic(vals[:-1-i-period+offset], fastk_days = fastk_days,
#      15                                          slowk_days = slowk_days,
#      16                                          slowd_days = slowd_days)
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in stochastic(vals, fastk_days, slowk_days, slowd_days)
#       3
#       4 def stochastic(vals, fastk_days = 7, slowk_days = 3, slowd_days = 3):
# ----> 5     fastk_val = fastk(vals[-fastk_days-1:-1])
#       6     slowk_val = slowk(vals[-slowk_days-1:-1])
#       7     slowd_val = slowd(vals[-slowd_days-1:-1])
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in fastk(vals)
#      22
#      23 def fastk(vals):
# ---> 24     t_close = vals[-1]
#      25     t_high = max(vals)
#      26     t_low = min(vals)
#
# IndexError: list index out of range
