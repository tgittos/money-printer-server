# %%
import sys 
sys.path.append('./../../src')

# python shit
from datetime import datetime

# my shit
from lib.finnhub.data import FinnhubData as finnhub
from lib.oscillators import macd_over_period, stochastic_over_period
from lib.charts import chart

# %%
ticker = 'UWMC'

fh = finnhub()
data = fh.get_historical_data(ticker, fh.get_daily_closings, days = 180)

data.index = data['t']
data.sort_index()
data.drop_duplicates()
# Out:
#                                       t      o      l      h      c        v
# t
# 2021-01-22 21:00:00 2021-01-22 21:00:00  11.30  11.35  11.43  11.45    80424
# 2021-01-25 21:00:00 2021-01-25 21:00:00  10.70  10.85  10.74  10.85    61245
# 2021-01-26 21:00:00 2021-01-26 21:00:00  10.07  10.07  10.12  10.16   135272
# 2021-01-27 21:00:00 2021-01-27 21:00:00  10.01  10.26  10.03  10.26    68884
# 2021-01-28 21:00:00 2021-01-28 21:00:00   9.90   9.96   9.98  10.03    51278
# 2021-01-29 21:00:00 2021-01-29 21:00:00   9.91   9.91   9.99  10.00    39248
# 2021-02-01 21:00:00 2021-02-01 21:00:00  10.10  10.10  10.25  10.25    48956
# 2021-02-02 21:00:00 2021-02-02 21:00:00  10.31  10.33  10.38  10.40    60792
# 2021-02-03 21:00:00 2021-02-03 21:00:00  11.20  11.54  11.75  12.08  1571101
# 2021-02-04 21:00:00 2021-02-04 21:00:00  10.35  10.39  10.38  10.49    54805
# 2021-02-05 21:00:00 2021-02-05 21:00:00   9.95   9.99   9.95  10.02    51712
# 2021-02-08 21:00:00 2021-02-08 21:00:00   9.50   9.51   9.54   9.57    78530
# 2021-02-09 21:00:00 2021-02-09 21:00:00   9.23   9.28   9.25   9.30   113508
# 2021-02-10 21:00:00 2021-02-10 21:00:00   9.02   9.09   9.03   9.09    34898
# 2021-02-11 21:00:00 2021-02-11 21:00:00   9.10   9.20   9.14   9.20    33122
# 2021-02-12 21:00:00 2021-02-12 21:00:00   9.00   9.02   9.02   9.02    23103
# 2021-02-16 21:00:00 2021-02-16 21:00:00   8.97   8.97   9.09   9.09   532021
# 2021-02-17 21:00:00 2021-02-17 21:00:00   8.76   8.86   8.77   8.86   191515
# 2021-02-18 21:00:00 2021-02-18 21:00:00   8.52   8.61   8.56   8.61   257199
# 2021-02-19 21:00:00 2021-02-19 21:00:00   8.23   8.32   8.27   8.32    72310
# 2021-02-22 21:00:00 2021-02-22 21:00:00   7.97   8.01   7.98   8.05    78203
# 2021-02-23 21:00:00 2021-02-23 21:00:00   7.69   8.04   7.90   8.04   381285
# 2021-02-24 21:00:00 2021-02-24 21:00:00   7.92   7.96   7.92   8.04   405060
# 2021-02-25 21:00:00 2021-02-25 21:00:00   7.60   7.64   7.61   7.71   345867
# 2021-02-26 21:00:00 2021-02-26 21:00:00   7.53   7.57   7.60   7.60   346627
# 2021-03-01 21:00:00 2021-03-01 21:00:00   7.57   7.63   7.63   7.63   380727
# 2021-03-02 21:00:00 2021-03-02 21:00:00   8.90   9.13   9.19   9.50  1119053
# 2021-03-03 21:00:00 2021-03-03 21:00:00   9.54   9.62   9.89  10.07  1117302
# 2021-03-04 21:00:00 2021-03-04 21:00:00   8.68   8.74   8.78   8.99   212744
# 2021-03-05 21:00:00 2021-03-05 21:00:00   8.56   8.68   8.65   8.79    49522
# 2021-03-08 21:00:00 2021-03-08 21:00:00   8.14   8.16   8.16   8.27    24750
# 2021-03-09 21:00:00 2021-03-09 21:00:00   8.38   8.68   8.60   8.68   111049
# 2021-03-10 21:00:00 2021-03-10 21:00:00   8.55   8.58   8.59   8.65    68244
# 2021-03-11 21:00:00 2021-03-11 21:00:00   8.57   8.65   8.70   8.70    48761
# 2021-03-12 21:00:00 2021-03-12 21:00:00   8.25   8.28   8.33   8.35    51273
# 2021-03-15 20:00:00 2021-03-15 20:00:00   8.32   8.40   8.38   8.40    43673
# 2021-03-16 20:00:00 2021-03-16 20:00:00   8.40   8.45   8.47   8.47    17759

# %%
days = 60

chart_data = list(data['c'].tail(days))

macd_vals = macd_over_period(list(data['c']), days)

macd_line = list([i[0] for i in macd_vals])[-1-days:-1]
sig_line = list([i[1] for i in macd_vals])[-1-days:-1]
histo = list([i[2] for i in macd_vals])[-1-days:-1]

oscillator_dicts = [
    { 'chart': 'line', 'data': macd_line, 'label': 'macd' },
    { 'chart': 'line', 'data': sig_line, 'label': 'signal' },
    { 'chart': 'bar', 'data': histo, 'label': ''}
]

data_dicts = [
    { 'label': 'close', 'data': chart_data }
]

chart(ticker, data_dicts, oscillator_dicts)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-ff97dca3da7f> in <module>
#       3 chart_data = list(data['c'].tail(days))
#       4
# ----> 5 macd_vals = macd_over_period(list(data['c']), days)
#       6
#       7 macd_line = list([i[0] for i in macd_vals])[-1-days:-1]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in macd_over_period(vals, period)
#      47 def macd_over_period(vals, period):
#      48     m_vals = list([macd(vals[:-i]) for i in range(len(vals)-26, 0, -1)])
# ---> 49     ms_vals = list([ema(m_vals[:-i], 9, 2) for i in range(period, 0, -1)])
#      50     real_m_vals = m_vals[-period-1:-1]
#      51     histos = [t[0] - t[1] for t in list(zip(real_m_vals, ms_vals))]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in <listcomp>(.0)
#      47 def macd_over_period(vals, period):
#      48     m_vals = list([macd(vals[:-i]) for i in range(len(vals)-26, 0, -1)])
# ---> 49     ms_vals = list([ema(m_vals[:-i], 9, 2) for i in range(period, 0, -1)])
#      50     real_m_vals = m_vals[-period-1:-1]
#      51     histos = [t[0] - t[1] for t in list(zip(real_m_vals, ms_vals))]
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in ema(d, period, smoothing)
#      38     for i in range(0, period):
#      39         if i == 0:
# ---> 40             sma_val = sma(d)
#      41             vals = vals + [int(d[-period]) * k + sma_val]
#      42         else:
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in sma(vals)
#      19
#      20 def sma(vals):
# ---> 21     return sum(vals) / len(vals)
#      22
#      23 def fastk(vals):
#
# ZeroDivisionError: division by zero

# %%
stochastic_vals = stochastic_over_period(list(data['c']), days)

fastk_data = list([i[0] for i in stochastic_vals])
slowd_data = list([i[2] for i in stochastic_vals])

oscillator_dicts = [
    { 'chart': 'line', 'data': fastk_data, 'label': 'fastk'},
    { 'chart': 'line', 'data': slowd_data, 'label': 'slowd'}
]

data_dicts = [
    { 'label': 'close', 'data': chart_data }
]

chart(ticker, data_dicts, oscillator_dicts)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-5c3eda815a4e> in <module>
# ----> 1 stochastic_vals = stochastic_over_period(list(data['c']), days)
#       2
#       3 fastk_data = list([i[0] for i in stochastic_vals])
#       4 slowd_data = list([i[2] for i in stochastic_vals])
#       5
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in stochastic_over_period(vals, period, fastk_days, slowk_days, slowd_days)
#      12     ret_vals = [[0, 0, 0]] * period
#      13     for i in range(0, period):
# ---> 14         fastk, slowk, slowd = stochastic(vals[:-1-i-period+offset], fastk_days = fastk_days,
#      15                                          slowk_days = slowk_days,
#      16                                          slowd_days = slowd_days)
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in stochastic(vals, fastk_days, slowk_days, slowd_days)
#       3
#       4 def stochastic(vals, fastk_days = 7, slowk_days = 3, slowd_days = 3):
# ----> 5     fastk_val = fastk(vals[-fastk_days-1:-1])
#       6     slowk_val = slowk(vals[-slowk_days-1:-1])
#       7     slowd_val = slowd(vals[-slowd_days-1:-1])
#
# ~/src/money_printer/learnin/src/lib/oscillators.py in fastk(vals)
#      22
#      23 def fastk(vals):
# ---> 24     t_close = vals[-1]
#      25     t_high = max(vals)
#      26     t_low = min(vals)
#
# IndexError: list index out of range
